# %%
# %matplotlib inline
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=(10,4)

# %% [markdown]
# Numpy
# https://numpy.org/
# pre-installed, very fast framework

# %% [markdown]
# # making up data for good purposes / morally neutral

# %%
# an array of number across the range that's evenly spaced 
np.linspace(10,50,17) #min, max, steps
# Out:
# array([10. , 12.5, 15. , 17.5, 20. , 22.5, 25. , 27.5, 30. , 32.5, 35. ,
#        37.5, 40. , 42.5, 45. , 47.5, 50. ])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
some_good_numbers=np.linspace(0,100,16)

# %%
pd.Series(some_good_numbers)
# Out:
# 0       0.000000
# 1       6.666667
# 2      13.333333
# 3      20.000000
# 4      26.666667
# 5      33.333333
# 6      40.000000
# 7      46.666667
# 8      53.333333
# 9      60.000000
# 10     66.666667
# 11     73.333333
# 12     80.000000
# 13     86.666667
# 14     93.333333
# 15    100.000000
# dtype: float64

# %%
pd.Series(some_good_numbers).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # randomness

# %%
np.random.uniform(size=25)
# Out:
# array([0.81361969, 0.49561958, 0.18539287, 0.50193159, 0.08531145,
#        0.53571393, 0.88873037, 0.70794526, 0.64852689, 0.54237799,
#        0.39985391, 0.97751128, 0.0764367 , 0.68178998, 0.77597566,
#        0.05888644, 0.32006722, 0.35676815, 0.78263747, 0.63344412,
#        0.74967041, 0.15785353, 0.59813432, 0.02808003, 0.15853022])

# %%
np.random.uniform(-10,10,size=25)
# Out:
# array([ 1.26760976,  3.83413132,  8.18147569,  0.83133871, -1.72313821,
#         8.75060388, -7.36667651, -6.84488049, -3.66224258,  7.27527821,
#        -1.92929812,  9.39502565,  5.61526664,  4.11490553, -1.65297376,
#        -4.18779949, -4.65203853, -7.35980482, -2.60943956,  4.1200008 ,
#        -5.60190886,  5.03228504,  3.33387433, -3.83716058, -6.8809063 ])

# %%
rnums=np.random.uniform(0,100,size=25)

# %%
pd.Series(rnums).plot(kind="bar")
# Out:
# <Axes: >

# %%
a_bunch=np.random.uniform(0,100,size=10000)

# %%
pd.Series(a_bunch).plot(kind="hist")
#???
# Out:
# <Axes: ylabel='Frequency'>

# %%
some_normal_numbers=np.random.normal(size=1000000)

# %%
pd.Series(some_normal_numberbs).plot(kind="hist",bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pd.Series(some_normal_numbers).plot(kind="hist",bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # periodic data 周期数据

# %%
np.sin(3)
# input x, output y
# Out:
# np.float64(0.1411200080598672)

# %%
np.sin(np.pi)
# Out:
# np.float64(1.2246467991473532e-16)

# %%
np.sin([0,1,2,3,4])
# Out:
# array([ 0.        ,  0.84147098,  0.90929743,  0.14112001, -0.7568025 ])

# %%
np.sin(np.linspace(0,20,100))
# Out:
# array([ 0.        ,  0.20064886,  0.39313661,  0.56963411,  0.72296256,
#         0.84688556,  0.93636273,  0.98775469,  0.99897117,  0.96955595,
#         0.90070545,  0.79522006,  0.65739025,  0.49282204,  0.30820902,
#         0.11106004, -0.09060615, -0.28858706, -0.47483011, -0.64176014,
#        -0.7825875 , -0.89158426, -0.96431712, -0.99782778, -0.99075324,
#        -0.94338126, -0.85763861, -0.73701276, -0.58640998, -0.41195583,
#        -0.22074597, -0.0205576 ,  0.18046693,  0.37415123,  0.55261747,
#         0.7086068 ,  0.83577457,  0.92894843,  0.98433866,  0.99969234,
#         0.97438499,  0.90944594,  0.8075165 ,  0.6727425 ,  0.51060568,
#         0.32770071,  0.13146699, -0.07011396, -0.26884313, -0.45663749,
#        -0.62585878, -0.76962418, -0.88208623, -0.95867071, -0.99626264,
#        -0.99333304, -0.95000106, -0.86802917, -0.75075145, -0.60293801,
#        -0.43060093, -0.24074979, -0.0411065 ,  0.16020873,  0.35500771,
# ...

# %%
pd.Series(np.sin(np.linspace(0,20,100))).plot(kind="line")
# Out:
# <Axes: >

# %%
noisy=np.sin(np.linspace(-20,20,100)) + np.random.uniform(-0.5,0.5,size=100)

# %%
pd.Series(noisy).plot()
# Out:
# <Axes: >

# %% [markdown]
# # correlation study

# %%
df=pd.DataFrame(
    {
        "a":np.linspace(0,100,50),
        "b":np.sin(np.linspace(0,40,50))+10,
        "c":np.linspace(200,75,50)+np.random.uniform(-5,5,50),
        "d":np.random.uniform(0,25,size=50)
    }
)

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter",x="a",y="b")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df=df.sample(len(df)).reset_index(drop=True) #not taking the order into account, shuffle it

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind="scatter",x="c",y="a")
# Out:
# <Axes: xlabel='c', ylabel='a'>

# %%
df.plot(kind="scatter",x="c",y="d") #c and d no relations
# Out:
# <Axes: xlabel='c', ylabel='d'>

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='a', ylabel='a'>, <Axes: xlabel='b', ylabel='a'>,
#         <Axes: xlabel='c', ylabel='a'>, <Axes: xlabel='d', ylabel='a'>],
#        [<Axes: xlabel='a', ylabel='b'>, <Axes: xlabel='b', ylabel='b'>,
#         <Axes: xlabel='c', ylabel='b'>, <Axes: xlabel='d', ylabel='b'>],
#        [<Axes: xlabel='a', ylabel='c'>, <Axes: xlabel='b', ylabel='c'>,
#         <Axes: xlabel='c', ylabel='c'>, <Axes: xlabel='d', ylabel='c'>],
#        [<Axes: xlabel='a', ylabel='d'>, <Axes: xlabel='b', ylabel='d'>,
#         <Axes: xlabel='c', ylabel='d'>, <Axes: xlabel='d', ylabel='d'>]],
#       dtype=object)

# %% [markdown]
# # actual correlation values

# %%
df.corr() #pearson corelation coefficient
# Out:
#           a         b         c         d
# a  1.000000  0.001719 -0.997361  0.290646
# b  0.001719  1.000000 -0.002216 -0.098495
# c -0.997361 -0.002216  1.000000 -0.290943
# d  0.290646 -0.098495 -0.290943  1.000000

# %% [markdown]
# # real data

# %%
df_new = pd.read_csv("./github-topics-by-economy.csv").set_index("iso2_code")

# %%
df_new
# Out:
#              python  javascript     react  hacktoberfest  typescript  \
# iso2_code
# AR         0.039609    0.065067  0.058653       0.005784    0.022493
# AT         0.143863    0.096892  0.016085       0.103127    0.056965
# AU         0.065165    0.051515  0.053479       0.038584    0.039427
# BD         0.024566    0.046559  0.035475       0.001271    0.008511
# BE         0.134137    0.076613  0.045815       0.076655    0.033513
# ...             ...         ...       ...            ...         ...
# US         0.028277    0.020119  0.017519       0.014956    0.010669
# UZ         0.000000    0.015633  0.000000       0.000000    0.000000
# VE         0.000000    0.036792  0.000000       0.000000    0.000000
# VN         0.019918    0.028190  0.028847       0.004431    0.016845
# ZA         0.016711    0.025470  0.015814       0.000000    0.000000
#
#                java    nodejs       css    docker      html  ...      game  \
# ...

# %%
df_new.loc["US"]["rust"]
# Out:
# np.float64(0.0053268280082186)

# %%
df_new.loc["CN"]["react"]
# Out:
# np.float64(0.0214606989412306)

# %%
df_new.loc["US"]["react"]
# Out:
# np.float64(0.0175185136860917)

# %%
df_new.corr()
# Out:
#                     python  javascript     react  hacktoberfest  typescript  \
# python            1.000000    0.585947  0.366915       0.733542    0.461957
# javascript        0.585947    1.000000  0.624952       0.424563    0.581962
# react             0.366915    0.624952  1.000000       0.248786    0.634372
# hacktoberfest     0.733542    0.424563  0.248786       1.000000    0.368323
# typescript        0.461957    0.581962  0.634372       0.368323    1.000000
# java              0.612837    0.523005  0.279680       0.601238    0.556103
# nodejs            0.143030    0.153410  0.289580      -0.020501    0.440581
# css              -0.246902   -0.014515  0.007712      -0.340120   -0.062631
# docker            0.392906    0.157989  0.263785       0.299651    0.637894
# html             -0.211861   -0.059033 -0.007816      -0.317520   -0.002694
# reactjs          -0.265028   -0.134920 -0.054063      -0.280909   -0.096695
# ...

# %%
df_new_slice=df_new[["python","php","java","javascript","css"]]

# %%
pd.plotting.scatter_matrix(df_new_slice)
# Out:
# array([[<Axes: xlabel='python', ylabel='python'>,
#         <Axes: xlabel='php', ylabel='python'>,
#         <Axes: xlabel='java', ylabel='python'>,
#         <Axes: xlabel='javascript', ylabel='python'>,
#         <Axes: xlabel='css', ylabel='python'>],
#        [<Axes: xlabel='python', ylabel='php'>,
#         <Axes: xlabel='php', ylabel='php'>,
#         <Axes: xlabel='java', ylabel='php'>,
#         <Axes: xlabel='javascript', ylabel='php'>,
#         <Axes: xlabel='css', ylabel='php'>],
#        [<Axes: xlabel='python', ylabel='java'>,
#         <Axes: xlabel='php', ylabel='java'>,
#         <Axes: xlabel='java', ylabel='java'>,
#         <Axes: xlabel='javascript', ylabel='java'>,
#         <Axes: xlabel='css', ylabel='java'>],
#        [<Axes: xlabel='python', ylabel='javascript'>,
#         <Axes: xlabel='php', ylabel='javascript'>,
#         <Axes: xlabel='java', ylabel='javascript'>,
#         <Axes: xlabel='javascript', ylabel='javascript'>,
# ...

# %%
df_new.corr()["python"].sort_values(ascending=False)
#picking out individual language to find the corr
# Out:
# python              1.000000
# hacktoberfest       0.733542
# java                0.612837
# javascript          0.585947
# typescript          0.461957
# docker              0.392906
# react               0.366915
# php                 0.267850
# documentation       0.212785
# machine-learning    0.200749
# linux               0.182088
# kubernetes          0.163709
# nodejs              0.143030
# rust                0.122608
# golang              0.104656
# deep-learning       0.096169
# api                 0.081185
# blockchain          0.070675
# go                  0.058190
# dotfiles            0.057860
# cli                 0.012881
# game               -0.007755
# vue                -0.012221
# cpp                -0.019139
# blog               -0.030812
# python3            -0.039061
# website            -0.040422
# csharp             -0.059876
# android            -0.088875
# ios                -0.098411
# kotlin             -0.107205
# django             -0.108539
# ...

# %% [markdown]
# # transpose!

# %%
df_new.T.corr()
# Out:
# iso2_code        AR        AT        AU        BD        BE        BG  \
# iso2_code
# AR         1.000000  0.524220  0.779648  0.907110  0.590837  0.711644
# AT         0.524220  1.000000  0.779421  0.355682  0.930824  0.461678
# AU         0.779648  0.779421  1.000000  0.593629  0.833766  0.603541
# BD         0.907110  0.355682  0.593629  1.000000  0.449863  0.573053
# BE         0.590837  0.930824  0.833766  0.449863  1.000000  0.490000
# ...             ...       ...       ...       ...       ...       ...
# US         0.734447  0.842247  0.934125  0.531746  0.886672  0.550268
# UZ         0.543278  0.395217  0.376539  0.503584  0.378850  0.832768
# VE         0.543278  0.395217  0.376539  0.503584  0.378850  0.832768
# VN         0.898248  0.541174  0.775018  0.804208  0.573887  0.634077
# ZA         0.786915  0.614647  0.728705  0.656676  0.737894  0.797733
#
# iso2_code        BR        BY        CA        CH  ...        SG        TH  \
# ...

# %%
country_slice_df=df_new.T[["CN","US","CA","JP","IN"]]

# %%
country_slice_df.corr()
# Out:
# iso2_code        CN        US        CA        JP        IN
# iso2_code
# CN         1.000000  0.513478  0.505503  0.643677  0.262069
# US         0.513478  1.000000  0.958069  0.724529  0.781079
# CA         0.505503  0.958069  1.000000  0.720660  0.819941
# JP         0.643677  0.724529  0.720660  1.000000  0.347229
# IN         0.262069  0.781079  0.819941  0.347229  1.000000

# %%
pd.plotting.scatter_matrix(country_slice_df)
# Out:
# array([[<Axes: xlabel='CN', ylabel='CN'>,
#         <Axes: xlabel='US', ylabel='CN'>,
#         <Axes: xlabel='CA', ylabel='CN'>,
#         <Axes: xlabel='JP', ylabel='CN'>,
#         <Axes: xlabel='IN', ylabel='CN'>],
#        [<Axes: xlabel='CN', ylabel='US'>,
#         <Axes: xlabel='US', ylabel='US'>,
#         <Axes: xlabel='CA', ylabel='US'>,
#         <Axes: xlabel='JP', ylabel='US'>,
#         <Axes: xlabel='IN', ylabel='US'>],
#        [<Axes: xlabel='CN', ylabel='CA'>,
#         <Axes: xlabel='US', ylabel='CA'>,
#         <Axes: xlabel='CA', ylabel='CA'>,
#         <Axes: xlabel='JP', ylabel='CA'>,
#         <Axes: xlabel='IN', ylabel='CA'>],
#        [<Axes: xlabel='CN', ylabel='JP'>,
#         <Axes: xlabel='US', ylabel='JP'>,
#         <Axes: xlabel='CA', ylabel='JP'>,
#         <Axes: xlabel='JP', ylabel='JP'>,
#         <Axes: xlabel='IN', ylabel='JP'>],
#        [<Axes: xlabel='CN', ylabel='IN'>,
#         <Axes: xlabel='US', ylabel='IN'>,
# ...

# %% [markdown]
# # linear correlation

# %%
a = np.sin(np.linspace(0,50,100))*20
b = np.cos(np.linspace(0,50,100))*10

# %%
periodic_df=pd.DataFrame({"a":a,"b":b})

# %%
periodic_df.plot()
# Out:
# <Axes: >

# %%
periodic_df.plot(kind="scatter",x="a",y="b")
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# # clustering
#
# ## dimensional reduction
#
# dimension = column in ds
#
# t-SNE

# %%
df_topics = df_new.T
df_econ=df_new

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 8.7 MB/s eta 0:00:0000:010:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 9.0 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
from sklearn.manifold import TSNE

# %%
tsne=TSNE(n_components=2,n_iter=3000).fit_transform(df_topics)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
tsne[:10]
# Out:
# array([[-1.7947882,  3.4509184],
#        [-1.7445031,  3.43179  ],
#        [-1.7270652,  3.3862154],
#        [-2.036175 ,  3.1406171],
#        [-1.9090011,  2.9785283],
#        [-2.0089455,  3.0027823],
#        [-1.3490576,  2.6035318],
#        [-0.677316 ,  2.1013472],
#        [-2.0113733,  2.2889605],
#        [-0.7610136,  2.0103304]], dtype=float32)

# %%
tsne_df=pd.DataFrame(tsne,index=df_topics.index,columns=["x","y"])

# %%
tsne_df.plot(kind="scatter",x="x",y="y")
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
fig, ax = plt.subplots() # create a matplotlib axis
tsne_df.plot.scatter(0, 1, ax=ax, figsize=(8, 8)) # figsize sets the size of the figure
for k, v in tsne_df.iterrows(): # annotate with matplotlib for every row
    ax.annotate(k, v)
